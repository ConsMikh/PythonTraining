# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
hist_req = pd.read_csv('socgaz_hist_REQ.csv', sep = ';', header = None)
hist_req.head(2)
# Out:
#           0                                     1   2   3            4   \
# 0  398286020  34db1301-24f7-11ec-8980-0050569c399d   0   0  0600-023318
# 1  398269377  fc701360-ce18-11eb-8912-0050569c399d   0   0  0800-002955
#
#        5                        6   \
# 0  Д14732  2021-10-04 12:58:22.000
# 1   Д0343  2021-06-15 23:33:55.000
#
#                                                   7   \
# 0  142326, Московская обл, Чеховский р-н, Васькино д
# 1  142530, Московская обл, Электрогорск г, 5-я Юг...
#
#                                                   8          9   \
# 0  Газификация жилого дома по адресу: Московская ...  Жилой дом
# 1  жилой дом, Московская область, г. Электрогорск...  Жилой дом
#
#                                10                             11         12  \
# 0                           Лично  Соколова Анастасия Николаевна  Физ. лицо
# 1  Внешняя информационная система  Тюменева Светлана Анатольевна  Физ. лицо
#
# ...

# %%
columnnames = {
    0: 'SETTL_FID',
    1: 'REQ_GUID',
    2: 'IsDell',
    3: 'ДелоАннулировано',
    4: 'Номер',
    5: 'НомерДела',
    6: 'Дата',
    7: 'Адрес',
    8: 'ОбъектПрисоединения',
    9: 'Тип объекта',
    10: 'СпособПодачиЗаявления',
    11: 'Заявитель',
    12: 'Тип заявителя',
    13: 'AGR_GUID',
    14: 'AGR.AGR_GUID'
}

# %%
hist_req = hist_req.rename(columns=columnnames)
hist_req.head(2)
# Out:
#    SETTL_FID                              REQ_GUID  IsDell  ДелоАннулировано  \
# 0  398286020  34db1301-24f7-11ec-8980-0050569c399d       0                 0
# 1  398269377  fc701360-ce18-11eb-8912-0050569c399d       0                 0
#
#          Номер НомерДела                     Дата  \
# 0  0600-023318    Д14732  2021-10-04 12:58:22.000
# 1  0800-002955     Д0343  2021-06-15 23:33:55.000
#
#                                                Адрес  \
# 0  142326, Московская обл, Чеховский р-н, Васькино д
# 1  142530, Московская обл, Электрогорск г, 5-я Юг...
#
#                                  ОбъектПрисоединения Тип объекта  \
# 0  Газификация жилого дома по адресу: Московская ...   Жилой дом
# 1  жилой дом, Московская область, г. Электрогорск...   Жилой дом
#
#             СпособПодачиЗаявления                      Заявитель  \
# 0                           Лично  Соколова Анастасия Николаевна
# 1  Внешняя информационная система  Тюменева Светлана Анатольевна
#
# ...

# %%
hist_req[15] = pd.to_datetime(hist_req[15])

# %%
hist_req.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267275 entries, 0 to 267274
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   SETTL_FID              267275 non-null  int64
#  1   REQ_GUID               267275 non-null  object
#  2   IsDell                 267275 non-null  int64
#  3   ДелоАннулировано       267275 non-null  int64
#  4   Номер                  267275 non-null  object
#  5   НомерДела              265640 non-null  object
#  6   Дата                   267269 non-null  object
#  7   Адрес                  267218 non-null  object
#  8   ОбъектПрисоединения    267275 non-null  object
#  9   Тип объекта            265109 non-null  object
#  10  СпособПодачиЗаявления  267263 non-null  object
#  11  Заявитель              267104 non-null  object
#  12  Тип заявителя          266300 non-null  object
#  13  AGR_GUID               267275 non-null  object
# ...

# %%
hist_req['REQ_GUID'].nunique()
# Out:
# 89123

# %%
hist_req_maxdate = hist_req.groupby('REQ_GUID')[15].max().index
hist_req_maxdate
# Out:
# Index(['00009fb8-c92e-11eb-890a-0050569c399d',
#        '000213d8-1b9d-11ec-8980-0050569c399d',
#        '0002355c-717d-11ec-8980-0050569c399d',
#        '0003daf9-2c21-11ec-8980-0050569c399d',
#        '0003db03-2c21-11ec-8980-0050569c399d',
#        '00054962-5db6-11ec-8980-0050569c399d',
#        '000569c2-f5ef-11eb-8955-0050569c399d',
#        '0005cc30-dee4-11eb-8933-0050569c399d',
#        '0007b150-0a62-11ec-8971-0050569c399d',
#        '0008c820-c2dc-11eb-8901-0050569c399d',
#        ...
#        'fff70d8c-d1f9-11eb-891a-0050569c399d',
#        'fff8354c-c082-11eb-88fc-0050569c399d',
#        'fff8fbe7-2bfb-11ec-8980-0050569c399d',
#        'fffa4bbd-d653-11eb-8922-0050569c399d',
#        'fffa9f99-4551-11ec-8980-0050569c399d',
#        'fffba75a-4214-11ec-8980-0050569c399d',
#        'fffbc956-2145-11ec-8980-0050569c399d',
#        'fffd7b12-d013-11eb-8917-0050569c399d',
#        'fffe5069-53ba-11ec-8980-0050569c399d',
#        'fffed62e-f117-11eb-894f-0050569c399d'],
# ...

# %%
hist_req.loc[:,hist_req.columns != 15].columns
# Out:
# Index(['SETTL_FID', 'REQ_GUID', 'IsDell', 'ДелоАннулировано', 'Номер',
#        'НомерДела', 'Дата', 'Адрес', 'ОбъектПрисоединения', 'Тип объекта',
#        'СпособПодачиЗаявления', 'Заявитель', 'Тип заявителя', 'AGR_GUID',
#        'AGR.AGR_GUID'],
#       dtype='object')

# %%
hist_req_2 = hist_req.drop_duplicates(subset=hist_req.loc[:,hist_req.columns != 15].columns, keep='last')

# %%
hist_req_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 89216 entries, 586 to 267274
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   SETTL_FID              89216 non-null  int64
#  1   REQ_GUID               89216 non-null  object
#  2   IsDell                 89216 non-null  int64
#  3   ДелоАннулировано       89216 non-null  int64
#  4   Номер                  89216 non-null  object
#  5   НомерДела              88671 non-null  object
#  6   Дата                   89214 non-null  object
#  7   Адрес                  89197 non-null  object
#  8   ОбъектПрисоединения    89216 non-null  object
#  9   Тип объекта            88494 non-null  object
#  10  СпособПодачиЗаявления  89212 non-null  object
#  11  Заявитель              89159 non-null  object
#  12  Тип заявителя          88891 non-null  object
#  13  AGR_GUID               89216 non-null  object
# ...

# %%
hist_req_2['REQ_GUID'].nunique()
# Out:
# 89123

# %%
hist_req_2.groupby('REQ_GUID')['REQ_GUID'].count().sort_values()
# Out:
# REQ_GUID
# 00009fb8-c92e-11eb-890a-0050569c399d    1
# aaf9cf01-c48e-11eb-8905-0050569c399d    1
# aaf9ad10-d42f-11eb-891e-0050569c399d    1
# aaf87feb-c381-11eb-8903-0050569c399d    1
# aaf780c4-25a2-11ec-8980-0050569c399d    1
#                                        ..
# 5bb5c24e-7385-11ec-8980-0050569c399d    2
# 4f050848-7472-11ec-8980-0050569c399d    2
# 57e9b7aa-6fae-11ec-8980-0050569c399d    2
# fdae628a-7440-11ec-8980-0050569c399d    2
# f441d685-72c8-11ec-8980-0050569c399d    2
# Name: REQ_GUID, Length: 89123, dtype: int64

# %%
hist_req_2.loc[hist_req_2['REQ_GUID']=='f441d685-72c8-11ec-8980-0050569c399d']
# Out:
#         SETTL_FID                              REQ_GUID  IsDell  \
# 12387   398281384  f441d685-72c8-11ec-8980-0050569c399d       0
# 238325  398281384  f441d685-72c8-11ec-8980-0050569c399d       0
#
#         ДелоАннулировано        Номер НомерДела                     Дата  \
# 12387                  0  0100-000140    Д00127  2022-01-11 13:43:16.000
# 238325                 0  0100-000140    Д00127  2022-01-11 13:43:16.000
#
#                                                     Адрес  \
# 12387   141870, Московская обл, Дмитров г, Лупаново д,...
# 238325  141870, Московская обл, Дмитров г, Лупаново д,...
#
#                                       ОбъектПрисоединения Тип объекта  \
# 12387   жилой дом МЧРГ=7м3/ч на зем.уч. с кад.№50:04:0...   Жилой дом
# 238325  жилой дом МЧРГ=7м3/ч на зем.уч. с кад.№50:04:0...   Жилой дом
#
#        СпособПодачиЗаявления                 Заявитель Тип заявителя  \
# 12387                  Лично  Михеева Людмила Ивановна     Физ. лицо
# ...

# %%
hist_req.groupby('REQ_GUID').agg({15:'max'})
# Out:
#                                              15
# REQ_GUID
# 00009fb8-c92e-11eb-890a-0050569c399d 2022-02-13
# 000213d8-1b9d-11ec-8980-0050569c399d 2022-02-13
# 0002355c-717d-11ec-8980-0050569c399d 2022-02-13
# 0003daf9-2c21-11ec-8980-0050569c399d 2022-02-13
# 0003db03-2c21-11ec-8980-0050569c399d 2022-02-13
# ...                                         ...
# fffba75a-4214-11ec-8980-0050569c399d 2022-02-13
# fffbc956-2145-11ec-8980-0050569c399d 2022-02-13
# fffd7b12-d013-11eb-8917-0050569c399d 2022-02-13
# fffe5069-53ba-11ec-8980-0050569c399d 2022-02-13
# fffed62e-f117-11eb-894f-0050569c399d 2022-02-13
#
# [89123 rows x 1 columns]

# %%
hist_req.groupby('REQ_GUID')[15].idxmax()
# Out:
# 89123

# %%
hist_req.iloc[hist_req.groupby('REQ_GUID')[15].idxmax().values]
# Out:
#         SETTL_FID                              REQ_GUID  IsDell  \
# 87641   398272726  00009fb8-c92e-11eb-890a-0050569c399d       0
# 6769    398279879  000213d8-1b9d-11ec-8980-0050569c399d       0
# 39046   398281978  0002355c-717d-11ec-8980-0050569c399d       0
# 4523    398275656  0003daf9-2c21-11ec-8980-0050569c399d       0
# 24529   398271761  0003db03-2c21-11ec-8980-0050569c399d       0
# ...           ...                                   ...     ...
# 60408   398271506  fffba75a-4214-11ec-8980-0050569c399d       0
# 80996   398281657  fffbc956-2145-11ec-8980-0050569c399d       0
# 86544   398274709  fffd7b12-d013-11eb-8917-0050569c399d       0
# 267228  398287897  fffe5069-53ba-11ec-8980-0050569c399d       0
# 25248   398287962  fffed62e-f117-11eb-894f-0050569c399d       0
#
#         ДелоАннулировано        Номер НомерДела                     Дата  \
# 87641                  0  0500-012681     Д1648  2021-06-09 17:30:31.000
# ...
